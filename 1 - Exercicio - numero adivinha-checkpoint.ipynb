# %%
import random as rdm


aleatorio = rdm.randint(0,100)


n_tentativas = 0

while num_inserido != aleatorio:
    num_inserido = int(input('Insira um número'))
    n_tentativas += 1
    maiormenor = ['menor','maior']
    if num_inserido == aleatorio:
        print('Você acertou!!! Foram apenas ' + str(n_tentativas) + ' tentativas')
        break
    else:
                
        print('Errou!! O número secreto é ' + maiormenor[aleatorio>num_inserido] + ' que isso.')
        tentar_de_novo = input('Quer tentar de novo?')
        if tentar_de_novo != 'sim':
            break
# Out:
# Insira um número 33
# Errou!! O número secreto é maior que isso.
# Quer tentar de novo? sim
# Insira um número 55
# Errou!! O número secreto é maior que isso.
# Quer tentar de novo? sim
# Insira um número 77
# Errou!! O número secreto é maior que isso.
# Quer tentar de novo? sim
# Insira um número 99
# Errou!! O número secreto é menor que isso.
# Quer tentar de novo? sim
# Insira um número 83
# Errou!! O número secreto é menor que isso.
# Quer tentar de novo? sim
# Insira um número 80
# Errou!! O número secreto é menor que isso.
# Quer tentar de novo? sim
# Insira um número 78
# Errou!! O número secreto é maior que isso.
# Quer tentar de novo? sim
# Insira um número 79
# Você acertou!!! Foram apenas 8 tentativas
