# %%
#Crie um dicionário onde as chaves são nomes de municípios e os valores são PIB per capita. 

import pandas as pd
import requests
import wikipedia as wp
#from bs4 import BeautifulSoup

munpibpc = dict()

pibmpc_url = "https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_do_Brasil_por_PIB_per_capita"

wikippc = wp.page("Lista_de_munic%C3%ADpios_do_Brasil_por_PIB_per_capita").html().encode('UTF-8')
tabela_munppc = pd.read_html(wikippc)


print(minhatabela)
# Out:
# None
# /tmp/ipykernel_38546/3062827638.py:13: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sopa = BeautifulSoup(requests.get(pibmpc_url).text,'html')

# %%
#Permita inserir, remover e consultar municípios e retorne o município com maior e menor 
#PIB per capita.
#from urllib.request import urlopen
#import json
#url_lista_municipios = 'https://github.com/kelvins/municipios-brasileiros/raw/refs/heads/main/json/municipios.json'

#munjson = urlopen(url_lista_municipios)
#munjson = munjson.read()
#municipios = json.loads(munjson)

#municipios = pd.json_normalize(municipios)

#for municipio in municipios:
#    munpibpc[municipio]:
#minhatabela = sopa.find('table',{'class':'wikitable sortable jquery-tablesorter'})
